# %% [markdown]
# # Workout : Tensorflow vs Pytorch
#
# 1. Extract the code for stimulating tensorflow and pytorch
# 2. Using these parameters :
#     - epoch = 30
#     - maxIteration = 5
#
# 3. Save file name ending with suffix of accuracy(e.g: tf_90, pth_70)
#     - extract the code for stimulating tensorflow
#     - separate module (cv_image_tensorflow_model.py)
#     - extract the code for stimulatinng pytorch
#     - separate model (cv_image_pytorch_model.py)
#
# 4. Load the saved models with the highest accuracy for tensorflow and pytorch
# 5. Predict for same dataImages in new file: cv_image_tensorflow_vs_pytorch.py
# 6. Use timeit package to record runtime of both algorithm
#     - email the saved model (with highest accuracy) before 7pm without uploading to github
#     - Get your project dataset ready for presentation tomorrow

# %% [markdown]
# $
# \ Model \ for \ Pytorch
# $

# %%
import torch 
from torch import nn 
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt
import numpy as np
import torchvision
from sklearn.model_selection import train_test_split
import random
import cv2 as cv 
import timeit
import time

# %% [markdown]
# Load data

# %%
dataSet = 'master_dataset.npz'
with np.load(dataSet, allow_pickle=True) as data:
    dataImages = data['images']
    dataLabels = data['labels'].astype('int64')
    dataLabelNames = data['labelnames']

# %% [markdown]
# Convert size

# %%
N = len(dataImages)
shape = (N, 200, 200, 3)
y = np.empty(shape)

for i in range(N):
    y[i] = cv.resize(dataImages[i], [200,200], interpolation=cv.INTER_NEAREST)

dataImages = y

# %% [markdown]
# Normalize data

# %%
dataImages = dataImages / 255.0

# %%
print(dataLabels.dtype)
dataLabels = dataLabels.astype('int64')

print(dataLabels.dtype)
# Out:
# int64
# int64

# %% [markdown]
# Transfor to torch

# %%
dataImages2 = torch.Tensor(dataImages)

# %% [markdown]
# Convert to tuple

# %%
all_data = []
for i in range(len(dataImages2)):
   all_data.append([dataImages2[i], dataLabels[i]])

random.shuffle(all_data)

# %% [markdown]
# Based on tuple, split data into training and testing

# %%
train_size = int(0.75 * len(all_data))
test_size = len(all_data) - train_size
train_dataset, test_dataset, = torch.utils.data.random_split(all_data, [train_size, test_size])

# %% [markdown]
# Check the size of train_dataset and test_dataset

# %%
len(train_dataset), len(test_dataset)
# Out:
# (317, 106)

# %%
classes = {
    0: "afiq",
    1: "azureen",
    2: "gavin",
    3: "goke",
    4: "inamul",
    5: "jincheng",
    6: "mahmuda",
    7: "numan",
    8: "saseendran"
}

# %% [markdown]
# ### Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=batch_size)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size)

for X, y in test_dataloader:
    print("Shape of X [N, C, H, W]: ", X.shape)
    print("Shape of y: ", y.shape, y.dtype)
    break
# Out:
# Shape of X [N, C, H, W]:  torch.Size([20, 200, 200, 3])
# Shape of y:  torch.Size([20]) torch.int64

# %% [markdown]
# ### CPU device training.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
input_features = 3*200*200

# %% [markdown]
# ### Create model

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(input_features, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 9)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120000, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=512, out_features=9, bias=True)
#   )
# )

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    return loss, current

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    
    return test_loss, correct

# %% [markdown]
# 1. Run cell class NeuralNetwork
# 2. Run cell loss_fn & optimizer
# 3. Run cell def test
# 4. Run cell def train
# 5. Pastu skip yang lain & terus run yg ni

# %%
import os

maxIterations = 5
thresholdAcc = 0.9

testLoss = 0.0
testAcc = 0.0
epochs = 30

start = time.time()

for iter in range(maxIterations):

    print(f'Simulation {iter+1}/{maxIterations}', end='... ')

    for t in range(epochs):
        train(train_dataloader, model, loss_fn, optimizer)
        test_loss, testAcc = test(test_dataloader, model, loss_fn)

    # Save model if greater than threshold-accuracy 0.95
    if testAcc > thresholdAcc:
        file_name = f'pth_{(testAcc*100):.0f}.pth'
        torch.save(model.state_dict(), file_name)
        print("Saved PyTorch Model State")
        thresholdAcc = testAcc

end = time.time()
times = end - start
print('Time elapsed:', times)
print('Highest Acc =', thresholdAcc)
print('All task is done.')
# Out:
# Simulation 1/5... loss: 2.185797  [    0/  317]
# Test Error:
#  Accuracy: 38.7%, Avg loss: 2.177878
#
# loss: 2.166652  [    0/  317]
# Test Error:
#  Accuracy: 47.2%, Avg loss: 2.159613
#
# loss: 2.150229  [    0/  317]
# Test Error:
#  Accuracy: 50.9%, Avg loss: 2.141391
#
# loss: 2.131680  [    0/  317]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 2.122791
#
# loss: 2.113213  [    0/  317]
# Test Error:
#  Accuracy: 47.2%, Avg loss: 2.102739
#
# loss: 2.094452  [    0/  317]
# Test Error:
#  Accuracy: 49.1%, Avg loss: 2.081956
#
# loss: 2.074804  [    0/  317]
# Test Error:
#  Accuracy: 48.1%, Avg loss: 2.060345
#
# loss: 2.053852  [    0/  317]
# Test Error:
#  Accuracy: 48.1%, Avg loss: 2.038016
#
# loss: 2.032138  [    0/  317]
# Test Error:
#  Accuracy: 48.1%, Avg loss: 2.014360
#
# loss: 2.008949  [    0/  317]
# Test Error:
#  Accuracy: 49.1%, Avg loss: 1.989081
#
# loss: 1.984289  [    0/  317]
# Test Error:
#  Accuracy: 49.1%, Avg loss: 1.962823
#
# loss: 1.958309  [    0/  317]
# Test Error:
#  Accuracy: 49.1%, Avg loss: 1.935800
#
# loss: 1.930891  [    0/  317]
# Test Error:
#  Accuracy: 49.1%, Avg loss: 1.908019
#
# loss: 1.901282  [    0/  317]
# Test Error:
#  Accuracy: 50.9%, Avg loss: 1.879534
#
# loss: 1.870245  [    0/  317]
# Test Error:
#  Accuracy: 50.9%, Avg loss: 1.849955
#
# loss: 1.837663  [    0/  317]
# Test Error:
#  Accuracy: 51.9%, Avg loss: 1.819450
#
# loss: 1.803838  [    0/  317]
# Test Error:
#  Accuracy: 52.8%, Avg loss: 1.788200
#
# loss: 1.768297  [    0/  317]
# Test Error:
#  Accuracy: 54.7%, Avg loss: 1.756013
#
# loss: 1.732011  [    0/  317]
# Test Error:
#  Accuracy: 57.5%, Avg loss: 1.722999
#
# loss: 1.694352  [    0/  317]
# Test Error:
#  Accuracy: 59.4%, Avg loss: 1.689119
#
# loss: 1.656341  [    0/  317]
# Test Error:
#  Accuracy: 61.3%, Avg loss: 1.654305
#
# loss: 1.617356  [    0/  317]
# Test Error:
#  Accuracy: 61.3%, Avg loss: 1.618119
#
# loss: 1.576890  [    0/  317]
# Test Error:
#  Accuracy: 64.2%, Avg loss: 1.580844
#
# loss: 1.535450  [    0/  317]
# Test Error:
#  Accuracy: 66.0%, Avg loss: 1.542771
#
# loss: 1.493526  [    0/  317]
# Test Error:
#  Accuracy: 67.9%, Avg loss: 1.504258
#
# loss: 1.451964  [    0/  317]
# Test Error:
#  Accuracy: 71.7%, Avg loss: 1.465303
#
# loss: 1.410003  [    0/  317]
# Test Error:
#  Accuracy: 72.6%, Avg loss: 1.426118
#
# loss: 1.368402  [    0/  317]
# Test Error:
#  Accuracy: 74.5%, Avg loss: 1.386633
#
# loss: 1.326657  [    0/  317]
# Test Error:
#  Accuracy: 75.5%, Avg loss: 1.347432
#
# loss: 1.284963  [    0/  317]
# Test Error:
#  Accuracy: 76.4%, Avg loss: 1.308175
#
# Simulation 2/5... loss: 1.243707  [    0/  317]
# Test Error:
#  Accuracy: 76.4%, Avg loss: 1.269561
#
# loss: 1.203293  [    0/  317]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 1.231421
#
# loss: 1.164088  [    0/  317]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 1.193953
#
# loss: 1.126064  [    0/  317]
# Test Error:
#  Accuracy: 79.2%, Avg loss: 1.157274
#
# loss: 1.088513  [    0/  317]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 1.121460
#
# loss: 1.052279  [    0/  317]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 1.086673
#
# loss: 1.017342  [    0/  317]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 1.052907
#
# loss: 0.983736  [    0/  317]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 1.020308
#
# loss: 0.951485  [    0/  317]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.988798
#
# loss: 0.920414  [    0/  317]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.958353
#
# loss: 0.890584  [    0/  317]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.929032
#
# loss: 0.862038  [    0/  317]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.900875
#
# loss: 0.834634  [    0/  317]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.873955
#
# loss: 0.808593  [    0/  317]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.848189
#
# loss: 0.783701  [    0/  317]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.823540
#
# loss: 0.759959  [    0/  317]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.799912
#
# loss: 0.737182  [    0/  317]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.777342
#
# loss: 0.715579  [    0/  317]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.755729
#
# loss: 0.694787  [    0/  317]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.735081
#
# loss: 0.674660  [    0/  317]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.715420
#
# loss: 0.655679  [    0/  317]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.696689
#
# loss: 0.637451  [    0/  317]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.678914
#
# loss: 0.620013  [    0/  317]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.662006
#
# loss: 0.603508  [    0/  317]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.645727
#
# loss: 0.587217  [    0/  317]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.630288
#
# loss: 0.571774  [    0/  317]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.615608
#
# loss: 0.557000  [    0/  317]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.601586
#
# loss: 0.542991  [    0/  317]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.588161
#
# loss: 0.529372  [    0/  317]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.575388
#
# loss: 0.516513  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.563299
#
# Simulation 3/5... loss: 0.504292  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.551594
#
# loss: 0.492346  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.540536
#
# loss: 0.481061  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.529910
#
# loss: 0.469985  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.519757
#
# loss: 0.459444  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.509938
#
# loss: 0.449336  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.500639
#
# loss: 0.439699  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.491644
#
# loss: 0.430400  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.482974
#
# loss: 0.421464  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.474692
#
# loss: 0.412752  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.466636
#
# loss: 0.404489  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.459050
#
# loss: 0.396539  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.451574
#
# loss: 0.388681  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.444501
#
# loss: 0.381264  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.437592
#
# loss: 0.373816  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.430946
#
# loss: 0.366843  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.424517
#
# loss: 0.360022  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.418287
#
# loss: 0.353528  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.412200
#
# loss: 0.347071  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.406398
#
# loss: 0.341108  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.400656
#
# loss: 0.335118  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.395148
#
# loss: 0.329293  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.389861
#
# loss: 0.323777  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.384647
#
# loss: 0.318305  [    0/  317]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.379664
#
# loss: 0.313030  [    0/  317]
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.374753
#
# loss: 0.307980  [    0/  317]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.369960
#
# loss: 0.302902  [    0/  317]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.365398
#
# loss: 0.298177  [    0/  317]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.360937
#
# loss: 0.293436  [    0/  317]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.356591
#
# loss: 0.288859  [    0/  317]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.352372
#
# Simulation 4/5... loss: 0.284514  [    0/  317]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.348360
#
# loss: 0.280232  [    0/  317]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.344405
#
# loss: 0.276125  [    0/  317]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.340526
#
# loss: 0.271970  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.336761
#
# loss: 0.268038  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.333095
#
# loss: 0.264088  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.329538
#
# loss: 0.260305  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.326029
#
# loss: 0.256591  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.322694
#
# loss: 0.253049  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.319403
#
# loss: 0.249550  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.316184
#
# loss: 0.246019  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.313074
#
# loss: 0.242664  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.309977
#
# loss: 0.239277  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.306970
#
# loss: 0.235981  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.303961
#
# loss: 0.232744  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.301206
#
# loss: 0.229608  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.298462
#
# loss: 0.226597  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.295675
#
# loss: 0.223500  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.293062
#
# loss: 0.220651  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.290485
#
# loss: 0.217797  [    0/  317]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.287930
#
# loss: 0.214968  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.285507
#
# loss: 0.212164  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.283125
#
# loss: 0.209481  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.280724
#
# loss: 0.206868  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.278459
#
# loss: 0.204237  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.276173
#
# loss: 0.201690  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.273899
#
# loss: 0.199131  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.271727
#
# loss: 0.196695  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.269719
#
# loss: 0.194272  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.267544
#
# loss: 0.191881  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.265542
#
# Saved PyTorch Model State
# Simulation 5/5... loss: 0.189626  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.263527
#
# loss: 0.187312  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.261601
#
# loss: 0.185060  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.259717
#
# loss: 0.182882  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.257756
#
# loss: 0.180687  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.255991
#
# loss: 0.178509  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.254198
#
# loss: 0.176397  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.252366
#
# loss: 0.174316  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.250659
#
# loss: 0.172329  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.248931
#
# loss: 0.170297  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.247323
#
# loss: 0.168318  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.245643
#
# loss: 0.166407  [    0/  317]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.244048
#
# loss: 0.164448  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.242477
#
# loss: 0.162555  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.240925
#
# loss: 0.160759  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.239374
#
# loss: 0.158900  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.237920
#
# loss: 0.157082  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.236430
#
# loss: 0.155307  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.235008
#
# loss: 0.153614  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.233561
#
# loss: 0.151933  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.232173
#
# loss: 0.150187  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.230776
#
# loss: 0.148614  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.229424
#
# loss: 0.147042  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.228109
#
# loss: 0.145449  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.226864
#
# loss: 0.143805  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.225570
#
# loss: 0.142254  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.224353
#
# loss: 0.140745  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.223062
#
# loss: 0.139233  [    0/  317]
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.221960
#
# loss: 0.137750  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.220684
#
# loss: 0.136351  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.219563
#
# Saved PyTorch Model State
# Time elapsed: 1097.6804990768433
# Highest Acc = 0.9433962264150944
# All task is done.
